# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/제어공학1
# Out:
# /content/drive/MyDrive/제어공학1

# %%
# !git clone "https://github.com/Ted2s/ted2s.git"
# Out:
# Cloning into 'ted2s'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 18 (delta 4), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (18/18), 8.26 KiB | 845.00 KiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !git init

# %%
# !git config --global user.email "kdragon201062@gmail.com"
# !git config --global user.name "Ted2s"

# %%
# !git add .
# !git commit -m "Edit Readme.md"
# Out:
# [master 581be90] Edit Readme.md
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git remote add ted2s https://Ted2s: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@github.com/Ted2s/ted2s.git
# Out:
# error: remote ted2s already exists.

# %%
# !git push -u ted2s main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/Ted2s/ted2s.git'
